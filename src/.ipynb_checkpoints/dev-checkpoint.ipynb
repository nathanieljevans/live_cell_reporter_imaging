# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sbn

from tslearn.clustering import TimeSeriesKMeans, KernelKMeans
from tslearn.metrics import dtw

from tslearn.preprocessing import TimeSeriesScalerMeanVariance, TimeSeriesResampler

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

from sklearn.decomposition import PCA
from sklearn.svm import SVC

import argparse
from datetime import datetime

import sys 
import uuid
import os
# Out:
# /home/teddy/miniconda3/envs/lc_reporter/lib/python3.9/site-packages/tslearn/bases/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)

# %%
class O: 
    def __init__(self): 
        O.load = ['raw']
        O.data = ['/home/teddy/local/live_cell_reporter_imaging/data/HER2_EFM192A_data_11-1-21/HER2_EFM192A_data_11-1-21/']
        O.drug = ['neratinib']
        O.resample_sz = [75]
        O.nclus = [5]
        O.sensitive_line = ['WT']
        O.resistant_line = ['T798I']
args = O()

# %%
print('\nsloading data...')
load = args.load[0].lower()
data_dir = args.data[0]
datasets = [x for x in os.listdir(data_dir) if os.path.isdir(data_dir + x)]

print('# of datasets to load:',len(datasets))

series_sel = pd.read_csv(data_dir + datasets[0] + '/' + load + '/clover_all_cell.csv').columns[1:-3]

_datas = []
for dataset in datasets: 
    cl_path = data_dir + dataset + '/' + load + '/clover_all_cell.csv'
    ms_path = data_dir + dataset + '/' + load + '/mscarlet_all_cell.csv'
    _clover = pd.read_csv(cl_path)
    _mscarl = pd.read_csv(ms_path)
    _data = _clover.merge(_mscarl, on=['track_index', 'cell__treatment'], how='inner')
    _data = _data.assign(dataset=dataset)
    _datas.append(_data)

data = pd.concat(_datas, axis=0)

clover_sel = [f'{x}_x' for x in series_sel]
mscarl_sel = [f'{x}_y' for x in series_sel]

data = data.assign(drug = [x.split('_')[-1] for x in data.cell__treatment])
data = data.assign(cell_line = [x.split('_', maxsplit=5)[0] for x in data.cell__treatment])
data = data.assign(mutant = [x.split('_', maxsplit=5)[-2] for x in data.cell__treatment])

data.head()
# Out:
# sloading data...
# # of datasets to load: 14
#                                    track_index       0_x      15_x      30_x  \
# 0  95_1000820656_efm192a_erk_akt__wt_untreated  0.614204  0.613644  0.604215
# 1  95_1000824156_efm192a_erk_akt__wt_untreated  0.796560  0.675594  0.681481
# 2  95_1000820506_efm192a_erk_akt__wt_untreated  0.929764  0.830124  0.762827
# 3   4_1000034926_efm192a_erk_akt__wt_untreated  0.648266  0.584383  0.518272
# 4  98_1000855728_efm192a_erk_akt__wt_untreated  0.705933  0.661050  0.637281
#
#        45_x      60_x      75_x      90_x     105_x     120_x  ...    2190_y  \
# 0  0.618300  0.619398  0.657024  0.713075  0.695760  0.726159  ...  0.079882
# 1  0.660498  0.661479  0.717524  0.756510  0.765050  0.765040  ...  0.250697
# 2  0.776301  0.758100  0.758652  0.761263  0.710535  0.697256  ...  0.562772
# 3  0.520088  0.488933  0.540514  0.603546  0.628614  0.599961  ...  0.653183
# 4  0.571563  0.542889  0.514811  0.501832  0.494177  0.502280  ...  0.768634
#
#      2205_y    2220_y    2235_y  site_y  median_y       dataset       drug  \
# 0  0.067956  0.075988  0.082853      95  0.294573  H210514_Set1  untreated
# 1  0.243494  0.245351  0.243322      95  0.348082  H210514_Set1  untreated
# 2  0.489134  0.552784  0.620420      95  0.623733  H210514_Set1  untreated
# 3  0.622701  0.613495  0.611405       4  0.608579  H210514_Set1  untreated
# 4  0.773763  0.790160  0.818764      98  0.673437  H210514_Set1  untreated
#
#    cell_line  mutant
# 0    efm192a      wt
# 1    efm192a      wt
# 2    efm192a      wt
# 3    efm192a      wt
# 4    efm192a      wt
#
# [5 rows x 310 columns]

# %%
[x for x in data.track_index.values if 'T759del' in x]
# Out:
# ['20_1000088444_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000316726_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000315853_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000333953_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000330209_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000328397_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000099405_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000311231_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000310322_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000316494_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000097884_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000311376_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000335473_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000329623_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000315145_efm192a_erk_akt__L755_T759del_untreated',
#  '77_1000323902_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000326728_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000317097_efm192a_erk_akt__L755_T759del_untreated',
#  '20_1000088044_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000335684_efm192a_erk_akt__L755_T759del_untreated',
#  '21_1000093411_efm192a_erk_akt__L755_T759del_untreated',
#  '77_1000324147_efm192a_erk_akt__L755_T759del_untreated',
#  '20_1000086380_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000310172_efm192a_erk_akt__L755_T759del_untreated',
#  '24_1000109907_efm192a_erk_akt__L755_T759del_untreated',
#  '77_1000322605_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000313866_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000329772_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000099046_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000095478_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000315414_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000312931_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000330822_efm192a_erk_akt__L755_T759del_untreated',
#  '20_1000087130_efm192a_erk_akt__L755_T759del_untreated',
#  '23_1000106055_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000329371_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000312116_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000326550_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000333026_efm192a_erk_akt__L755_T759del_untreated',
#  '24_1000111398_efm192a_erk_akt__L755_T759del_untreated',
#  '77_1000321696_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000331661_efm192a_erk_akt__L755_T759del_untreated',
#  '77_1000322054_efm192a_erk_akt__L755_T759del_untreated',
#  '23_1000103533_efm192a_erk_akt__L755_T759del_untreated',
#  '24_1000112953_efm192a_erk_akt__L755_T759del_untreated',
#  '21_1000091960_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000098248_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000318599_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000309659_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000332062_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000312778_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000328024_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000096736_efm192a_erk_akt__L755_T759del_untreated',
#  '23_1000105676_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000319894_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000312370_efm192a_erk_akt__L755_T759del_untreated',
#  '21_1000091084_efm192a_erk_akt__L755_T759del_untreated',
#  '21_1000091486_efm192a_erk_akt__L755_T759del_untreated',
#  '20_1000087277_efm192a_erk_akt__L755_T759del_untreated',
#  '23_1000108422_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000099917_efm192a_erk_akt__L755_T759del_untreated',
#  '77_1000322754_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000310920_efm192a_erk_akt__L755_T759del_untreated',
#  '24_1000111259_efm192a_erk_akt__L755_T759del_untreated',
#  '24_1000110732_efm192a_erk_akt__L755_T759del_untreated',
#  '23_1000103707_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000099189_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000331484_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000332683_efm192a_erk_akt__L755_T759del_untreated',
#  '21_1000090846_efm192a_erk_akt__L755_T759del_untreated',
#  '77_1000322931_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000335282_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000097030_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000100640_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000336436_efm192a_erk_akt__L755_T759del_untreated',
#  '20_1000088298_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000318407_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000315560_efm192a_erk_akt__L755_T759del_untreated',
#  '24_1000110935_efm192a_erk_akt__L755_T759del_untreated',
#  '21_1000090389_efm192a_erk_akt__L755_T759del_untreated',
#  '23_1000104464_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000317744_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000334254_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000319534_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000327162_efm192a_erk_akt__L755_T759del_untreated',
#  '23_1000104940_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000329219_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000329922_efm192a_erk_akt__L755_T759del_untreated',
#  '21_1000092780_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000328979_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000330359_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000320058_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000096541_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000319386_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000098679_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000311707_efm192a_erk_akt__L755_T759del_untreated',
#  '23_1000103358_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000335013_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000316002_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000100301_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000335910_efm192a_erk_akt__L755_T759del_untreated',
#  '78_1000327688_efm192a_erk_akt__L755_T759del_untreated',
#  '21_1000090049_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000320205_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000316247_efm192a_erk_akt__L755_T759del_untreated',
#  '23_1000106205_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000317464_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000333550_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000315703_efm192a_erk_akt__L755_T759del_untreated',
#  '76_1000318748_efm192a_erk_akt__L755_T759del_untreated',
#  '21_1000090662_efm192a_erk_akt__L755_T759del_untreated',
#  '23_1000104080_efm192a_erk_akt__L755_T759del_untreated',
#  '77_1000322455_efm192a_erk_akt__L755_T759del_untreated',
#  '23_1000106995_efm192a_erk_akt__L755_T759del_untreated',
#  '22_1000099555_efm192a_erk_akt__L755_T759del_untreated',
#  '20_1000086082_efm192a_erk_akt__L755_T759del_untreated',
#  '75_1000312520_efm192a_erk_akt__L755_T759del_untreated',
#  '24_1000110186_efm192a_erk_akt__L755_T759del_untreated',
#  '79_1000336060_efm192a_erk_akt__L755_T759del_untreated',
#  '21_1000091810_efm192a_erk_akt__L755_T759del_untreated',
#  '176_1000811979_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000557351_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000837649_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000543528_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000815017_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000823870_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000548589_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000826020_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000813038_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000816044_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000557890_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000801996_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000535233_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000549308_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000552590_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000552443_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000803596_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000814743_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000841112_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000810433_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000816482_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000806459_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000547202_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000556983_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000804899_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000538454_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000550933_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000828616_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000828372_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000534403_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000816332_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000535071_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000840250_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000801011_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000533868_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000803873_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000554771_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000830934_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000811833_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000546627_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000806607_efm192a_erk_akt__L755_T759del_neratinib',
#  '124_1000567371_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000560135_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000838003_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000821584_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000832958_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000819940_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000545771_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000831104_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000823558_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000828132_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000802951_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000551581_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000813455_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000542414_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000801567_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000539654_efm192a_erk_akt__L755_T759del_neratinib',
#  '124_1000563716_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000536972_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000555245_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000553228_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000547047_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000558156_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000548912_efm192a_erk_akt__L755_T759del_neratinib',
#  '124_1000564755_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000816841_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000838851_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000543678_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000829181_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000841344_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000837853_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000842388_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000806052_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000832407_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000821142_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000836284_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000814375_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000827360_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000825505_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000534243_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000800044_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000835900_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000809316_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000807608_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000831531_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000826324_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000819761_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000818262_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000803256_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000559243_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000822282_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000819372_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000806199_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000831960_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000822929_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000545519_efm192a_erk_akt__L755_T759del_neratinib',
#  '124_1000565270_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000534705_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000558413_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000820910_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000535923_efm192a_erk_akt__L755_T759del_neratinib',
#  '124_1000565927_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000845236_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000822435_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000549786_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000537122_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000536059_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000825872_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000553688_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000840658_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000553375_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000550605_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000837358_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000838461_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000533420_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000814076_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000814537_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000550402_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000820234_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000826992_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000829485_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000558748_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000836773_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000561565_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000559726_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000810981_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000822734_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000535609_efm192a_erk_akt__L755_T759del_neratinib',
#  '124_1000565558_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000553528_efm192a_erk_akt__L755_T759del_neratinib',
#  '124_1000563416_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000538146_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000546475_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000824440_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000830433_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000839856_efm192a_erk_akt__L755_T759del_neratinib',
#  '124_1000564142_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000539143_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000805147_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000829331_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000544963_efm192a_erk_akt__L755_T759del_neratinib',
#  '124_1000565082_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000539504_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000537976_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000827641_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000559976_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000843892_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000819195_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000541662_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000534018_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000838297_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000818121_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000561222_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000826852_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000538694_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000804669_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000546780_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000831380_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000548739_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000552907_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000560734_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000841749_efm192a_erk_akt__L755_T759del_neratinib',
#  '124_1000567652_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000800634_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000827804_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000823260_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000839483_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000841499_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000833124_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000552747_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000832808_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000815258_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000551431_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000809914_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000542111_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000829701_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000812193_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000826622_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000809614_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000818648_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000805462_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000822123_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000550151_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000821333_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000821882_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000560884_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000802527_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000543382_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000801309_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000547380_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000829850_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000813605_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000841898_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000827142_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000555496_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000544730_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000551733_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000539300_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000820084_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000802380_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000824021_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000558925_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000830067_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000844476_efm192a_erk_akt__L755_T759del_neratinib',
#  '120_1000538843_efm192a_erk_akt__L755_T759del_neratinib',
#  '124_1000563566_efm192a_erk_akt__L755_T759del_neratinib',
#  '175_1000805902_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000542261_efm192a_erk_akt__L755_T759del_neratinib',
#  '179_1000835597_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000818798_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000550755_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000560333_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000818498_efm192a_erk_akt__L755_T759del_neratinib',
#  '122_1000553999_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000820613_efm192a_erk_akt__L755_T759del_neratinib',
#  '176_1000811213_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000543232_efm192a_erk_akt__L755_T759del_neratinib',
#  '178_1000830784_efm192a_erk_akt__L755_T759del_neratinib',
#  '121_1000543928_efm192a_erk_akt__L755_T759del_neratinib',
#  '177_1000823707_efm192a_erk_akt__L755_T759del_neratinib',
#  '123_1000562246_efm192a_erk_akt__L755_T759del_neratinib',
#  '223_1001096868_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '223_1001093934_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '276_1001268163_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '223_1001092166_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001283881_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001081613_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001076578_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '223_1001092016_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001080052_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001281247_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001274797_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001261205_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '276_1001268834_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001277415_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '223_1001095424_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001078952_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001079557_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '276_1001266921_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001086130_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001087941_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001276554_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001070029_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001276029_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001264129_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001067565_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001081463_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001066139_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001075215_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001282967_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001275216_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001068167_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001071350_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001065412_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '276_1001268581_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001282817_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001088987_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001074825_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001073931_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001079404_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001068353_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001276715_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001273894_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001263036_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001271818_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '223_1001093351_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001072745_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001071711_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001278187_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001065270_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001275049_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001082548_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001270970_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001085212_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001067210_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001085381_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001271420_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001261672_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001273003_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001100374_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001101873_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001102321_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001275696_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001084611_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001084191_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001084024_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001099932_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001271122_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001085631_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001083672_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001080986_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001272658_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001071054_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001066750_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001069777_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '276_1001269132_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001282481_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001088413_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '276_1001267814_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001085857_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001089205_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001102854_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001088559_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '276_1001268353_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001277091_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001070262_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '279_1001285651_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001262035_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001100788_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001102559_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001282296_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '279_1001289489_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001274535_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001078312_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001086815_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '223_1001092770_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '279_1001286589_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001079896_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '279_1001286979_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001070745_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001262895_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001263194_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001074081_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001098539_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001261820_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001102171_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001072266_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001078112_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '223_1001095797_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001087018_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001263484_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001276941_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001274361_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001102021_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001281396_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001076874_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '276_1001268980_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001283732_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '279_1001286441_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001098688_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001076071_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001083503_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '223_1001094452_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001262257_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001260614_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001084428_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001099730_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001283544_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001086508_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '279_1001289246_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001089589_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '275_1001260922_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001284294_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001070900_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '276_1001265941_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '279_1001288060_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '223_1001092617_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001083174_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '276_1001266646_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001075449_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001276189_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001083024_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001274065_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '277_1001274213_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '279_1001289833_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001072888_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001282062_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '223_1001096557_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '279_1001288358_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001101419_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001077605_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '276_1001267348_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001076231_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '220_1001069208_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '221_1001075689_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '278_1001280879_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '224_1001099532_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001079255_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '222_1001089440_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '223_1001096010_efm192a_erk_akt__L755_T759del_trastuzumab',
#  '18_1000151600_efm192a__L755T759del_untreated',
#  '60_1000540270_efm192a__L755T759del_untreated',
#  '17_1000136837_efm192a__L755T759del_untreated',
#  '17_1000139597_efm192a__L755T759del_untreated',
#  '17_1000134765_efm192a__L755T759del_untreated',
#  '18_1000148933_efm192a__L755T759del_untreated',
#  '61_1000544779_efm192a__L755T759del_untreated',
#  '16_1000133285_efm192a__L755T759del_untreated',
#  '17_1000141506_efm192a__L755T759del_untreated',
#  '61_1000545578_efm192a__L755T759del_untreated',
#  '17_1000142297_efm192a__L755T759del_untreated',
#  '18_1000150110_efm192a__L755T759del_untreated',
#  '61_1000542509_efm192a__L755T759del_untreated',
#  '18_1000145207_efm192a__L755T759del_untreated',
#  '60_1000540676_efm192a__L755T759del_untreated',
#  '18_1000145700_efm192a__L755T759del_untreated',
#  '61_1000546507_efm192a__L755T759del_untreated',
#  '61_1000546165_efm192a__L755T759del_untreated',
#  '61_1000544364_efm192a__L755T759del_untreated',
#  '17_1000137991_efm192a__L755T759del_untreated',
#  '17_1000134915_efm192a__L755T759del_untreated',
#  '19_1000154272_efm192a__L755T759del_untreated',
#  '18_1000149112_efm192a__L755T759del_untreated',
#  '61_1000546315_efm192a__L755T759del_untreated',
#  '19_1000154864_efm192a__L755T759del_untreated',
#  '61_1000547443_efm192a__L755T759del_untreated',
#  '17_1000140426_efm192a__L755T759del_untreated',
#  '17_1000142553_efm192a__L755T759del_untreated',
#  '61_1000550638_efm192a__L755T759del_untreated',
#  '62_1000555995_efm192a__L755T759del_untreated',
#  '18_1000149810_efm192a__L755T759del_untreated',
#  '62_1000552079_efm192a__L755T759del_untreated',
#  '61_1000545200_efm192a__L755T759del_untreated',
#  '61_1000548870_efm192a__L755T759del_untreated',
#  '18_1000150260_efm192a__L755T759del_untreated',
#  '60_1000541357_efm192a__L755T759del_untreated',
#  '17_1000139036_efm192a__L755T759del_untreated',
#  '61_1000550332_efm192a__L755T759del_untreated',
#  '17_1000134501_efm192a__L755T759del_untreated',
#  '18_1000151212_efm192a__L755T759del_untreated',
#  '18_1000145963_efm192a__L755T759del_untreated',
#  '18_1000149659_efm192a__L755T759del_untreated',
#  '61_1000549766_efm192a__L755T759del_untreated',
#  '61_1000543483_efm192a__L755T759del_untreated',
#  '18_1000147807_efm192a__L755T759del_untreated',
#  '62_1000554277_efm192a__L755T759del_untreated',
#  '63_1000556901_efm192a__L755T759del_untreated',
#  '18_1000146113_efm192a__L755T759del_untreated',
#  '60_1000541207_efm192a__L755T759del_untreated',
#  '62_1000552578_efm192a__L755T759del_untreated',
#  '60_1000539156_efm192a__L755T759del_untreated',
#  '17_1000140846_efm192a__L755T759del_untreated',
#  '17_1000139447_efm192a__L755T759del_untreated',
#  '60_1000541909_efm192a__L755T759del_untreated',
#  '18_1000146990_efm192a__L755T759del_untreated',
#  '61_1000543961_efm192a__L755T759del_untreated',
#  '17_1000142142_efm192a__L755T759del_untreated',
#  '63_1000557542_efm192a__L755T759del_untreated',
#  '62_1000553019_efm192a__L755T759del_untreated',
#  '17_1000134203_efm192a__L755T759del_untreated',
#  '17_1000137637_efm192a__L755T759del_untreated',
#  '60_1000542175_efm192a__L755T759del_untreated',
#  '17_1000135254_efm192a__L755T759del_untreated',
#  '62_1000553313_efm192a__L755T759del_untreated',
#  '17_1000138280_efm192a__L755T759del_untreated',
#  '61_1000544514_efm192a__L755T759del_untreated',
#  '17_1000141656_efm192a__L755T759del_untreated',
#  '60_1000540826_efm192a__L755T759del_untreated',
#  '19_1000154422_efm192a__L755T759del_untreated',
#  '60_1000541580_efm192a__L755T759del_untreated',
#  '62_1000552277_efm192a__L755T759del_untreated',
#  '18_1000149262_efm192a__L755T759del_untreated',
#  '62_1000553881_efm192a__L755T759del_untreated',
#  '17_1000139299_efm192a__L755T759del_untreated',
#  '62_1000553648_efm192a__L755T759del_untreated',
#  '17_1000137787_efm192a__L755T759del_untreated',
#  '17_1000137486_efm192a__L755T759del_untreated',
#  '63_1000558278_efm192a__L755T759del_untreated',
#  '17_1000136408_efm192a__L755T759del_untreated',
#  '61_1000543184_efm192a__L755T759del_untreated',
#  '63_1000559395_efm192a__L755T759del_untreated',
#  '61_1000549302_efm192a__L755T759del_untreated',
#  '60_1000539918_efm192a__L755T759del_untreated',
#  '61_1000543334_efm192a__L755T759del_untreated',
#  '17_1000133770_efm192a__L755T759del_untreated',
#  '17_1000135403_efm192a__L755T759del_untreated',
#  '61_1000543783_efm192a__L755T759del_untreated',
#  '62_1000554427_efm192a__L755T759del_untreated',
#  '61_1000548637_efm192a__L755T759del_untreated',
#  '61_1000548381_efm192a__L755T759del_untreated',
#  '17_1000135065_efm192a__L755T759del_untreated',
#  '18_1000147657_efm192a__L755T759del_untreated',
#  '18_1000149509_efm192a__L755T759del_untreated',
#  '63_1000557160_efm192a__L755T759del_untreated',
#  '63_1000558451_efm192a__L755T759del_untreated',
#  '61_1000544214_efm192a__L755T759del_untreated',
#  '61_1000550182_efm192a__L755T759del_untreated',
#  '17_1000143112_efm192a__L755T759del_untreated',
#  '61_1000547230_efm192a__L755T759del_untreated',
#  '60_1000540976_efm192a__L755T759del_untreated',
#  '16_1000132120_efm192a__L755T759del_untreated',
#  '62_1000555345_efm192a__L755T759del_untreated',
#  '17_1000134351_efm192a__L755T759del_untreated',
#  '17_1000141992_efm192a__L755T759del_untreated',
#  '61_1000547080_efm192a__L755T759del_untreated',
#  '19_1000155163_efm192a__L755T759del_untreated',
#  '62_1000553169_efm192a__L755T759del_untreated',
#  '61_1000546016_efm192a__L755T759del_untreated',
#  '18_1000146840_efm192a__L755T759del_untreated',
#  '19_1000154122_efm192a__L755T759del_untreated',
#  '18_1000145518_efm192a__L755T759del_untreated',
#  '17_1000143341_efm192a__L755T759del_untreated',
#  '63_1000557310_efm192a__L755T759del_untreated',
#  '61_1000549562_efm192a__L755T759del_untreated',
#  '18_1000148425_efm192a__L755T759del_untreated',
#  '17_1000137207_efm192a__L755T759del_untreated',
#  '61_1000545353_efm192a__L755T759del_untreated',
#  '17_1000142974_efm192a__L755T759del_untreated',
#  '18_1000148575_efm192a__L755T759del_untreated',
#  '62_1000553508_efm192a__L755T759del_untreated',
#  '17_1000136261_efm192a__L755T759del_untreated',
#  '16_1000132525_efm192a__L755T759del_untreated',
#  '62_1000551915_efm192a__L755T759del_untreated',
#  '61_1000546657_efm192a__L755T759del_untreated',
#  '19_1000152785_efm192a__L755T759del_untreated',
#  '61_1000549156_efm192a__L755T759del_untreated',
#  '18_1000151749_efm192a__L755T759del_untreated',
#  '17_1000138779_efm192a__L755T759del_untreated',
#  '62_1000554098_efm192a__L755T759del_untreated',
#  '63_1000558118_efm192a__L755T759del_untreated',
#  '61_1000545034_efm192a__L755T759del_untreated',
#  '61_1000546806_efm192a__L755T759del_untreated',
#  '61_1000543633_efm192a__L755T759del_untreated',
#  '18_1000146582_efm192a__L755T759del_untreated',
#  '60_1000540420_efm192a__L755T759del_untreated',
#  '17_1000135805_efm192a__L755T759del_untreated',
#  '61_1000547874_efm192a__L755T759del_untreated',
#  '18_1000150921_efm192a__L755T759del_untreated',
#  '61_1000545728_efm192a__L755T759del_untreated',
#  '18_1000149960_efm192a__L755T759del_untreated',
#  '18_1000147140_efm192a__L755T759del_untreated',
#  '60_1000539769_efm192a__L755T759del_untreated',
#  '62_1000555049_efm192a__L755T759del_untreated',
#  '18_1000146320_efm192a__L755T759del_untreated',
#  '19_1000153387_efm192a__L755T759del_untreated',
#  '19_1000153672_efm192a__L755T759del_untreated',
#  '16_1000132674_efm192a__L755T759del_untreated',
#  '62_1000555607_efm192a__L755T759del_untreated',
#  '62_1000555756_efm192a__L755T759del_untreated',
#  '98_1000880263_efm192a__L755T759del_neratinib',
#  '142_1001366381_efm192a__L755T759del_neratinib',
#  '142_1001364087_efm192a__L755T759del_neratinib',
#  '142_1001364935_efm192a__L755T759del_neratinib',
#  '98_1000886949_efm192a__L755T759del_neratinib',
#  '142_1001367911_efm192a__L755T759del_neratinib',
#  '142_1001364785_efm192a__L755T759del_neratinib',
#  '142_1001366226_efm192a__L755T759del_neratinib',
#  '98_1000877163_efm192a__L755T759del_neratinib',
#  '98_1000882733_efm192a__L755T759del_neratinib',
#  '98_1000881117_efm192a__L755T759del_neratinib',
#  '141_1001350798_efm192a__L755T759del_neratinib',
#  '141_1001348434_efm192a__L755T759del_neratinib',
#  '98_1000877013_efm192a__L755T759del_neratinib',
#  '98_1000878157_efm192a__L755T759del_neratinib',
#  '98_1000877848_efm192a__L755T759del_neratinib',
#  '98_1000881311_efm192a__L755T759del_neratinib',
#  '142_1001358169_efm192a__L755T759del_neratinib',
#  '142_1001366931_efm192a__L755T759del_neratinib',
#  '142_1001358465_efm192a__L755T759del_neratinib',
#  '98_1000877573_efm192a__L755T759del_neratinib',
#  '142_1001356894_efm192a__L755T759del_neratinib',
#  '142_1001358319_efm192a__L755T759del_neratinib',
#  '140_1001338946_efm192a__L755T759del_neratinib',
#  '142_1001365090_efm192a__L755T759del_neratinib',
#  '142_1001364399_efm192a__L755T759del_neratinib',
#  '98_1000880413_efm192a__L755T759del_neratinib',
#  '98_1000879965_efm192a__L755T759del_neratinib',
#  '142_1001357363_efm192a__L755T759del_neratinib',
#  '142_1001367081_efm192a__L755T759del_neratinib',
#  '98_1000880565_efm192a__L755T759del_neratinib',
#  '142_1001362724_efm192a__L755T759del_neratinib',
#  '98_1000880865_efm192a__L755T759del_neratinib',
#  '96_1000870831_efm192a__L755T759del_neratinib',
#  '97_1000873054_efm192a__L755T759del_neratinib',
#  '142_1001358796_efm192a__L755T759del_neratinib',
#  '99_1000892094_efm192a__L755T759del_neratinib',
#  '142_1001364244_efm192a__L755T759del_neratinib',
#  '142_1001357045_efm192a__L755T759del_neratinib',
#  '141_1001353453_efm192a__L755T759del_neratinib',
#  '142_1001363416_efm192a__L755T759del_neratinib',
#  '142_1001355666_efm192a__L755T759del_neratinib',
#  '142_1001355825_efm192a__L755T759del_neratinib',
#  '141_1001348284_efm192a__L755T759del_neratinib',
#  '98_1000885439_efm192a__L755T759del_neratinib',
#  '98_1000885289_efm192a__L755T759del_neratinib',
#  '142_1001356383_efm192a__L755T759del_neratinib',
#  '140_1001340095_efm192a__L755T759del_neratinib',
#  '96_1000870572_efm192a__L755T759del_neratinib',
#  '98_1000884993_efm192a__L755T759del_neratinib',
#  '98_1000882205_efm192a__L755T759del_neratinib',
#  '142_1001359686_efm192a__L755T759del_neratinib',
#  '142_1001356658_efm192a__L755T759del_neratinib',
#  '99_1000891794_efm192a__L755T759del_neratinib',
#  '141_1001344533_efm192a__L755T759del_neratinib',
#  '97_1000873353_efm192a__L755T759del_neratinib',
#  '97_1000874798_efm192a__L755T759del_neratinib',
#  '142_1001358646_efm192a__L755T759del_neratinib',
#  '142_1001365459_efm192a__L755T759del_neratinib',
#  '142_1001361827_efm192a__L755T759del_neratinib',
#  '99_1000889075_efm192a__L755T759del_neratinib',
#  '99_1000891644_efm192a__L755T759del_neratinib',
#  '142_1001362150_efm192a__L755T759del_neratinib',
#  '140_1001339410_efm192a__L755T759del_neratinib',
#  '97_1000876063_efm192a__L755T759del_neratinib',
#  '142_1001362577_efm192a__L755T759del_neratinib',
#  '99_1000891378_efm192a__L755T759del_neratinib',
#  '141_1001350132_efm192a__L755T759del_neratinib',
#  '96_1000869358_efm192a__L755T759del_neratinib',
#  '142_1001360683_efm192a__L755T759del_neratinib',
#  '98_1000882893_efm192a__L755T759del_neratinib',
#  '98_1000878307_efm192a__L755T759del_neratinib',
#  '141_1001352035_efm192a__L755T759del_neratinib',
#  '141_1001349982_efm192a__L755T759del_neratinib',
#  '141_1001352907_efm192a__L755T759del_neratinib',
#  '99_1000892325_efm192a__L755T759del_neratinib',
#  '99_1000889372_efm192a__L755T759del_neratinib',
#  '98_1000885928_efm192a__L755T759del_neratinib',
#  '98_1000878461_efm192a__L755T759del_neratinib',
#  '99_1000892475_efm192a__L755T759del_neratinib',
#  '98_1000881913_efm192a__L755T759del_neratinib',
#  '142_1001359384_efm192a__L755T759del_neratinib',
#  '96_1000869808_efm192a__L755T759del_neratinib',
#  '142_1001361573_efm192a__L755T759del_neratinib',
#  '98_1000879229_efm192a__L755T759del_neratinib',
#  '141_1001351098_efm192a__L755T759del_neratinib',
#  '97_1000876789_efm192a__L755T759del_neratinib',
#  '142_1001359836_efm192a__L755T759del_neratinib',
#  '99_1000888618_efm192a__L755T759del_neratinib',
#  '142_1001359533_efm192a__L755T759del_neratinib',
#  '140_1001341920_efm192a__L755T759del_neratinib',
#  '142_1001359227_efm192a__L755T759del_neratinib',
#  '142_1001357916_efm192a__L755T759del_neratinib',
#  '142_1001355974_efm192a__L755T759del_neratinib',
#  '96_1000870184_efm192a__L755T759del_neratinib',
#  '97_1000875507_efm192a__L755T759del_neratinib',
#  '98_1000883244_efm192a__L755T759del_neratinib',
#  '99_1000893079_efm192a__L755T759del_neratinib',
#  '98_1000886745_efm192a__L755T759del_neratinib',
#  '141_1001348731_efm192a__L755T759del_neratinib',
#  '98_1000885628_efm192a__L755T759del_neratinib',
#  '98_1000881461_efm192a__L755T759del_neratinib',
#  '142_1001365833_efm192a__L755T759del_neratinib',
#  '140_1001338124_efm192a__L755T759del_neratinib',
#  '96_1000868947_efm192a__L755T759del_neratinib',
#  '98_1000886566_efm192a__L755T759del_neratinib',
#  '99_1000889225_efm192a__L755T759del_neratinib',
#  '141_1001345194_efm192a__L755T759del_neratinib',
#  '98_1000878689_efm192a__L755T759del_neratinib',
#  '143_1001373543_efm192a__L755T759del_neratinib',
#  '143_1001371387_efm192a__L755T759del_neratinib',
#  '99_1000888925_efm192a__L755T759del_neratinib',
#  '143_1001372647_efm192a__L755T759del_neratinib',
#  '141_1001349514_efm192a__L755T759del_neratinib',
#  '142_1001358963_efm192a__L755T759del_neratinib',
#  '99_1000889900_efm192a__L755T759del_neratinib',
#  '141_1001345028_efm192a__L755T759del_neratinib',
#  '98_1000884843_efm192a__L755T759del_neratinib',
#  '97_1000876377_efm192a__L755T759del_neratinib',
#  '141_1001346561_efm192a__L755T759del_neratinib',
#  '140_1001342868_efm192a__L755T759del_neratinib',
#  '143_1001373141_efm192a__L755T759del_neratinib',
#  '141_1001349664_efm192a__L755T759del_neratinib',
#  '141_1001352296_efm192a__L755T759del_neratinib',
#  '98_1000884393_efm192a__L755T759del_neratinib',
#  '143_1001371860_efm192a__L755T759del_neratinib',
#  '96_1000868764_efm192a__L755T759del_neratinib',
#  '98_1000877423_efm192a__L755T759del_neratinib',
#  '97_1000875796_efm192a__L755T759del_neratinib',
#  '143_1001374878_efm192a__L755T759del_neratinib',
#  '141_1001348134_efm192a__L755T759del_neratinib',
#  '141_1001348916_efm192a__L755T759del_neratinib',
#  '97_1000874645_efm192a__L755T759del_neratinib',
#  '142_1001366072_efm192a__L755T759del_neratinib',
#  '99_1000888308_efm192a__L755T759del_neratinib',
#  '142_1001367757_efm192a__L755T759del_neratinib',
#  '143_1001372464_efm192a__L755T759del_neratinib',
#  '142_1001362978_efm192a__L755T759del_neratinib',
#  '98_1000886083_efm192a__L755T759del_neratinib',
#  '142_1001360440_efm192a__L755T759del_neratinib',
#  '142_1001359981_efm192a__L755T759del_neratinib',
#  '142_1001360131_efm192a__L755T759del_neratinib',
#  '141_1001343980_efm192a__L755T759del_neratinib',
#  '141_1001347269_efm192a__L755T759del_neratinib',
#  '142_1001363161_efm192a__L755T759del_neratinib',
#  '140_1001337818_efm192a__L755T759del_neratinib',
#  '98_1000885778_efm192a__L755T759del_neratinib',
#  '141_1001350282_efm192a__L755T759del_neratinib',
#  '98_1000879079_efm192a__L755T759del_neratinib',
#  '141_1001349813_efm192a__L755T759del_neratinib',
#  '99_1000890443_efm192a__L755T759del_neratinib',
#  '141_1001349221_efm192a__L755T759del_neratinib',
#  '141_1001349367_efm192a__L755T759del_neratinib',
#  '98_1000883899_efm192a__L755T759del_neratinib',
#  '141_1001347410_efm192a__L755T759del_neratinib',
#  '98_1000879815_efm192a__L755T759del_neratinib',
#  '99_1000891228_efm192a__L755T759del_neratinib',
#  '98_1000882055_efm192a__L755T759del_neratinib',
#  '143_1001373691_efm192a__L755T759del_neratinib',
#  '140_1001340597_efm192a__L755T759del_neratinib',
#  '140_1001343018_efm192a__L755T759del_neratinib',
#  '96_1000870420_efm192a__L755T759del_neratinib',
#  '143_1001373907_efm192a__L755T759del_neratinib',
#  '98_1000884543_efm192a__L755T759del_neratinib',
#  '99_1000891078_efm192a__L755T759del_neratinib',
#  '142_1001363827_efm192a__L755T759del_neratinib',
#  '98_1000884094_efm192a__L755T759del_neratinib',
#  '141_1001346261_efm192a__L755T759del_neratinib',
#  '99_1000891944_efm192a__L755T759del_neratinib',
#  '143_1001372938_efm192a__L755T759del_neratinib',
#  '142_1001357766_efm192a__L755T759del_neratinib',
#  '98_1000887096_efm192a__L755T759del_neratinib',
#  '141_1001346053_efm192a__L755T759del_neratinib',
#  '98_1000879548_efm192a__L755T759del_neratinib',
#  '141_1001351248_efm192a__L755T759del_neratinib',
#  '143_1001374580_efm192a__L755T759del_neratinib',
#  '99_1000893788_efm192a__L755T759del_neratinib',
#  '98_1000883651_efm192a__L755T759del_neratinib',
#  '142_1001360290_efm192a__L755T759del_neratinib',
#  '98_1000880114_efm192a__L755T759del_neratinib',
#  '141_1001352513_efm192a__L755T759del_neratinib',
#  '142_1001366712_efm192a__L755T759del_neratinib',
#  '143_1001371587_efm192a__L755T759del_neratinib',
#  '141_1001348575_efm192a__L755T759del_neratinib',
#  '99_1000890293_efm192a__L755T759del_neratinib',
#  '140_1001340327_efm192a__L755T759del_neratinib',
#  '99_1000889600_efm192a__L755T759del_neratinib',
#  '140_1001343247_efm192a__L755T759del_neratinib',
#  '141_1001347560_efm192a__L755T759del_neratinib',
#  '98_1000886332_efm192a__L755T759del_neratinib',
#  '140_1001341771_efm192a__L755T759del_neratinib',
#  '98_1000884693_efm192a__L755T759del_neratinib',
#  '99_1000894251_efm192a__L755T759del_neratinib',
#  '140_1001342663_efm192a__L755T759del_neratinib',
#  '141_1001346823_efm192a__L755T759del_neratinib',
#  '141_1001346411_efm192a__L755T759del_neratinib',
#  '140_1001340895_efm192a__L755T759del_neratinib',
#  '98_1000880715_efm192a__L755T759del_neratinib',
#  '141_1001350948_efm192a__L755T759del_neratinib',
#  '140_1001339949_efm192a__L755T759del_neratinib',
#  '140_1001342519_efm192a__L755T759del_neratinib',
#  '99_1000890591_efm192a__L755T759del_neratinib',
#  '99_1000890824_efm192a__L755T759del_neratinib',
#  '142_1001356233_efm192a__L755T759del_neratinib',
#  '96_1000871316_efm192a__L755T759del_neratinib',
#  '143_1001374432_efm192a__L755T759del_neratinib',
#  '96_1000869658_efm192a__L755T759del_neratinib',
#  '99_1000892932_efm192a__L755T759del_neratinib',
#  '99_1000890143_efm192a__L755T759del_neratinib',
#  '143_1001375057_efm192a__L755T759del_neratinib',
#  '141_1001346973_efm192a__L755T759del_neratinib',
#  '97_1000873985_efm192a__L755T759del_neratinib',
#  '96_1000871466_efm192a__L755T759del_neratinib',
#  '99_1000888468_efm192a__L755T759del_neratinib',
#  '98_1000878838_efm192a__L755T759del_neratinib',
#  '96_1000869106_efm192a__L755T759del_neratinib',
#  '96_1000870981_efm192a__L755T759del_neratinib',
#  '140_1001341195_efm192a__L755T759del_neratinib',
#  '140_1001342372_efm192a__L755T759del_neratinib',
#  '99_1000889750_efm192a__L755T759del_neratinib',
#  '141_1001345753_efm192a__L755T759del_neratinib',
#  '143_1001374255_efm192a__L755T759del_neratinib',
#  '140_1001338796_efm192a__L755T759del_neratinib',
#  '99_1000893620_efm192a__L755T759del_neratinib',
#  '141_1001344284_efm192a__L755T759del_neratinib',
#  '140_1001339649_efm192a__L755T759del_neratinib',
#  '143_1001372795_efm192a__L755T759del_neratinib',
#  '143_1001375207_efm192a__L755T759del_neratinib',
#  '141_1001344878_efm192a__L755T759del_neratinib',
#  '142_1001367417_efm192a__L755T759del_neratinib',
#  '143_1001375357_efm192a__L755T759del_neratinib',
#  '140_1001339799_efm192a__L755T759del_neratinib',
#  '140_1001341045_efm192a__L755T759del_neratinib',
#  '141_1001345903_efm192a__L755T759del_neratinib',
#  '177_1001674507_efm192a__L755T759del_trastuzumab',
#  '221_1002004776_efm192a__L755T759del_trastuzumab',
#  '222_1002009570_efm192a__L755T759del_trastuzumab',
#  '223_1002019417_efm192a__L755T759del_trastuzumab',
#  '220_1001999899_efm192a__L755T759del_trastuzumab',
#  '221_1002006951_efm192a__L755T759del_trastuzumab',
#  '222_1002010025_efm192a__L755T759del_trastuzumab',
#  '223_1002019567_efm192a__L755T759del_trastuzumab',
#  '221_1002005076_efm192a__L755T759del_trastuzumab',
#  '178_1001681288_efm192a__L755T759del_trastuzumab',
#  '220_1002002519_efm192a__L755T759del_trastuzumab',
#  '222_1002014016_efm192a__L755T759del_trastuzumab',
#  '222_1002015035_efm192a__L755T759del_trastuzumab',
#  '222_1002011459_efm192a__L755T759del_trastuzumab',
#  '220_1002000200_efm192a__L755T759del_trastuzumab',
#  '220_1002003597_efm192a__L755T759del_trastuzumab',
#  '220_1002002369_efm192a__L755T759del_trastuzumab',
#  '178_1001680373_efm192a__L755T759del_trastuzumab',
#  '178_1001679924_efm192a__L755T759del_trastuzumab',
#  '222_1002011853_efm192a__L755T759del_trastuzumab',
#  '177_1001672828_efm192a__L755T759del_trastuzumab',
#  '177_1001673342_efm192a__L755T759del_trastuzumab',
#  '177_1001674118_efm192a__L755T759del_trastuzumab',
#  '222_1002010943_efm192a__L755T759del_trastuzumab',
#  '179_1001683809_efm192a__L755T759del_trastuzumab',
#  '220_1002003409_efm192a__L755T759del_trastuzumab',
#  '222_1002011225_efm192a__L755T759del_trastuzumab',
#  '178_1001678679_efm192a__L755T759del_trastuzumab',
#  '176_1001671171_efm192a__L755T759del_trastuzumab',
#  '222_1002015936_efm192a__L755T759del_trastuzumab',
#  '178_1001681619_efm192a__L755T759del_trastuzumab',
#  '221_1002006665_efm192a__L755T759del_trastuzumab',
#  '222_1002016089_efm192a__L755T759del_trastuzumab',
#  '177_1001674813_efm192a__L755T759del_trastuzumab',
#  '177_1001676481_efm192a__L755T759del_trastuzumab',
#  '223_1002020122_efm192a__L755T759del_trastuzumab',
#  '220_1002001895_efm192a__L755T759del_trastuzumab',
#  '222_1002012663_efm192a__L755T759del_trastuzumab',
#  '178_1001678372_efm192a__L755T759del_trastuzumab',
#  '176_1001671407_efm192a__L755T759del_trastuzumab',
#  '221_1002005680_efm192a__L755T759del_trastuzumab',
#  '221_1002004549_efm192a__L755T759del_trastuzumab',
#  '220_1002002099_efm192a__L755T759del_trastuzumab',
#  '220_1002000499_efm192a__L755T759del_trastuzumab',
#  '221_1002005981_efm192a__L755T759del_trastuzumab',
#  '222_1002015765_efm192a__L755T759del_trastuzumab',
#  '223_1002018682_efm192a__L755T759del_trastuzumab',
#  '222_1002009408_efm192a__L755T759del_trastuzumab',
#  '220_1002000050_efm192a__L755T759del_trastuzumab',
#  '177_1001673492_efm192a__L755T759del_trastuzumab',
#  '221_1002006134_efm192a__L755T759del_trastuzumab',
#  '179_1001682863_efm192a__L755T759del_trastuzumab',
#  '220_1002003146_efm192a__L755T759del_trastuzumab',
#  '176_1001671838_efm192a__L755T759del_trastuzumab',
#  '177_1001675353_efm192a__L755T759del_trastuzumab',
#  '222_1002010270_efm192a__L755T759del_trastuzumab',
#  '220_1002000350_efm192a__L755T759del_trastuzumab',
#  '222_1002010545_efm192a__L755T759del_trastuzumab',
#  '220_1002002817_efm192a__L755T759del_trastuzumab',
#  '222_1002014692_efm192a__L755T759del_trastuzumab',
#  '178_1001677605_efm192a__L755T759del_trastuzumab',
#  '222_1002013740_efm192a__L755T759del_trastuzumab',
#  '178_1001679330_efm192a__L755T759del_trastuzumab',
#  '220_1002002996_efm192a__L755T759del_trastuzumab',
#  '178_1001681846_efm192a__L755T759del_trastuzumab',
#  '222_1002013208_efm192a__L755T759del_trastuzumab',
#  '179_1001683660_efm192a__L755T759del_trastuzumab',
#  '178_1001678000_efm192a__L755T759del_trastuzumab',
#  '221_1002008024_efm192a__L755T759del_trastuzumab',
#  '178_1001678529_efm192a__L755T759del_trastuzumab',
#  '177_1001674365_efm192a__L755T759del_trastuzumab',
#  '223_1002019219_efm192a__L755T759del_trastuzumab',
#  '222_1002009720_efm192a__L755T759del_trastuzumab',
#  '220_1002001745_efm192a__L755T759del_trastuzumab',
#  '223_1002018832_efm192a__L755T759del_trastuzumab',
#  '177_1001674661_efm192a__L755T759del_trastuzumab',
#  '222_1002015491_efm192a__L755T759del_trastuzumab',
#  '178_1001681038_efm192a__L755T759del_trastuzumab',
#  '222_1002014837_efm192a__L755T759del_trastuzumab',
#  '220_1002001428_efm192a__L755T759del_trastuzumab',
#  '178_1001679031_efm192a__L755T759del_trastuzumab',
#  '178_1001679750_efm192a__L755T759del_trastuzumab',
#  '221_1002007593_efm192a__L755T759del_trastuzumab',
#  '221_1002005369_efm192a__L755T759del_trastuzumab',
#  '176_1001671024_efm192a__L755T759del_trastuzumab',
#  '223_1002021656_efm192a__L755T759del_trastuzumab',
#  '222_1002016538_efm192a__L755T759del_trastuzumab',
#  '179_1001682690_efm192a__L755T759del_trastuzumab',
#  '177_1001675113_efm192a__L755T759del_trastuzumab',
#  '176_1001670874_efm192a__L755T759del_trastuzumab',
#  '178_1001677156_efm192a__L755T759del_trastuzumab',
#  '222_1002012260_efm192a__L755T759del_trastuzumab',
#  '220_1001999327_efm192a__L755T759del_trastuzumab',
#  '178_1001680074_efm192a__L755T759del_trastuzumab',
#  '178_1001681436_efm192a__L755T759del_trastuzumab',
#  '222_1002016940_efm192a__L755T759del_trastuzumab',
#  '178_1001679594_efm192a__L755T759del_trastuzumab',
#  '222_1002017089_efm192a__L755T759del_trastuzumab',
#  '178_1001680224_efm192a__L755T759del_trastuzumab',
#  '179_1001683013_efm192a__L755T759del_trastuzumab',
#  '179_1001683515_efm192a__L755T759del_trastuzumab',
#  '223_1002019867_efm192a__L755T759del_trastuzumab',
#  '222_1002014166_efm192a__L755T759del_trastuzumab',
#  '176_1001670595_efm192a__L755T759del_trastuzumab',
#  '222_1002012028_efm192a__L755T759del_trastuzumab',
#  '220_1002002669_efm192a__L755T759del_trastuzumab',
#  '220_1002001278_efm192a__L755T759del_trastuzumab',
#  '177_1001675503_efm192a__L755T759del_trastuzumab',
#  '221_1002004926_efm192a__L755T759del_trastuzumab',
#  '177_1001676331_efm192a__L755T759del_trastuzumab',
#  '176_1001671982_efm192a__L755T759del_trastuzumab',
#  '223_1002021259_efm192a__L755T759del_trastuzumab',
#  '221_1002007100_efm192a__L755T759del_trastuzumab',
#  '221_1002007448_efm192a__L755T759del_trastuzumab',
#  '222_1002016238_efm192a__L755T759del_trastuzumab',
#  '223_1002021409_efm192a__L755T759del_trastuzumab',
#  '221_1002005831_efm192a__L755T759del_trastuzumab',
#  ...]

# %%
data[lambda x: x.drug == 'trastuzumab']
# Out:
#                                             track_index       0_x      15_x  \
# 622      204_1001989685_efm192a_erk_akt__wt_trastuzumab  0.919513  0.791309
# 623      204_1001986786_efm192a_erk_akt__wt_trastuzumab  1.318358  1.104472
# 624      297_1002871213_efm192a_erk_akt__wt_trastuzumab  0.565254  0.525296
# 625      297_1002865781_efm192a_erk_akt__wt_trastuzumab  0.628287  0.550122
# 626      299_1002884760_efm192a_erk_akt__wt_trastuzumab  0.720239  0.682602
# ...                                                 ...       ...       ...
# 2521   194_1000684741_efm192a_erk_akt__S963_trastuzumab  0.291862  0.264043
# 2522   194_1000683006_efm192a_erk_akt__S963_trastuzumab  0.581513  0.582768
# 2523   195_1000689146_efm192a_erk_akt__S963_trastuzumab  0.564247  0.531939
# 2524   207_1000706772_efm192a_erk_akt__S963_trastuzumab  0.392200  0.326384
# 2531  202_1000690883_efm192a_erk_akt__N488S_trastuzumab  0.232169  0.211851
#
#           30_x      45_x      60_x      75_x      90_x     105_x     120_x  \
# 622   0.643348  0.636877  0.610035  0.643806  0.653662  0.636423  0.643299
# 623   1.041894  0.992047  0.939191  1.091045  1.618872  1.642560  1.679468
# 624   0.514245  0.483715  0.576773  0.575702  0.554462  0.566891  0.579022
# 625   0.509990  0.568764  0.591910  0.596096  0.580491  0.583744  0.601825
# 626   0.666135  0.604362  0.696516  0.756407  0.799762  0.864445  0.857488
# ...        ...       ...       ...       ...       ...       ...       ...
# 2521  0.251329  0.251154  0.237630  0.230955  0.221852  0.217818  0.195709
# 2522  0.566893  0.563722  0.547340  0.528194  0.531447  0.502214  0.501203
# 2523  0.534312  0.523053  0.531012  0.543135  0.543562  0.556411  0.485228
# 2524  0.357390  0.392114  0.400074  0.417919  0.396069  0.376841  0.388821
# 2531  0.420649  0.341193  0.302369  0.344599  0.326505  0.314045  0.309726
#
#       ...    2190_y    2205_y    2220_y    2235_y  site_y  median_y  \
# 622   ...  0.669723  0.647661  0.636646  0.635588     204  0.670449
# 623   ...  0.416403  0.425001  0.414682  0.415011     204  0.460063
# 624   ...  0.537469  0.532544  0.518409  0.527261     297  0.569637
# 625   ...  0.178359  0.178359  0.178359  0.178359     297  0.415708
# 626   ...  0.216917  0.217519  0.384871  0.218468     299  0.635050
# ...   ...       ...       ...       ...       ...     ...       ...
# 2521  ...  0.587376  0.595860  0.610469  0.610066     194  0.560106
# 2522  ...  0.370491  0.373906  0.390356  0.388412     194  0.381906
# 2523  ...  0.280379  0.295018  0.295018  0.295018     195  0.401332
# 2524  ...  0.108965  0.529907  0.574234  0.111233     207  0.578633
# 2531  ...  0.145218  0.162247  0.095895  0.251309     202  0.406169
#
#               dataset         drug  cell_line  mutant
# 622      H210514_Set1  trastuzumab    efm192a      wt
# 623      H210514_Set1  trastuzumab    efm192a      wt
# 624      H210514_Set1  trastuzumab    efm192a      wt
# 625      H210514_Set1  trastuzumab    efm192a      wt
# 626      H210514_Set1  trastuzumab    efm192a      wt
# ...               ...          ...        ...     ...
# 2521  H210917_EFM192A  trastuzumab    efm192a    S963
# 2522  H210917_EFM192A  trastuzumab    efm192a    S963
# 2523  H210917_EFM192A  trastuzumab    efm192a    S963
# 2524  H210917_EFM192A  trastuzumab    efm192a    S963
# 2531  H210917_EFM192A  trastuzumab    efm192a   N488S
#
# [20671 rows x 310 columns]

# %%
data.drug.unique()
# Out:
# array(['untreated', 'neratinib', 'trastuzumab', 'T759del_untreated',
#        'T759del_neratinib', 'T759del_trastuzumab'], dtype=object)

# %%
########### FILTER TO DRUG & REMOVE NA ##############
print('\nfiltering to drug and removing NAs...')

# new 
assert data.drug.unique().shape[0] == 3, f'expected three unique treatments before drug filter, got: {data.drug.unique()}'

if args.drug[0].lower() == 'neratinib': 
    drug_ = '10nm_neratinib'
else: 
    drug_ = '10ug_ml_trastuzumab'

data = data[lambda x: x.drug.isin(['untreated', drug_])]
print('Data shape (untreated + drug):', data.shape)

# new <---- 
assert data.drug.unique().shape[0] == 2, f'expected two unique treatments, got: {data.drug.unique()}'

print('length of time series BEFORE removing time points with NA', len(clover_sel))
clover_sel = np.array(clover_sel)[~data[clover_sel].isna().any()]
mscarl_sel = np.array(mscarl_sel)[~data[mscarl_sel].isna().any()]
assert len(clover_sel) == len(mscarl_sel), 'clover timeseries is different length than mscarlet time series'
print('length of time series AFTER removing time points with NA', len(clover_sel))
# Out:
# filtering to drug and removing NAs...
# Data shape (untreated + drug): (20827, 310)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_4520/2105556598.py in <module>
#       9 data = data[lambda x: x.drug.isin(['untreated', drug_])]
#      10 print('Data shape (untreated + drug):', data.shape)
# ---> 11 assert data.drug.unique().shape[0] == 2, f'expected two unique treatments, got: {data.drug.unique()}'
#      12
#      13 print('length of time series BEFORE removing time points with NA', len(clover_sel))
#
# AssertionError: expected two unique treatments, got: ['untreated']

# %%
########### RESAMPLE ##############
print('\nresampling time series...')

X_train = np.stack([data[clover_sel], data[mscarl_sel]], axis=2)
print('Training data shape BEFORE resampling:', X_train.shape)

# Make time series shorter
X_train = TimeSeriesResampler(sz=args.resample_sz[0]).fit_transform(X_train)
print('Training data shape AFTER resampling:', X_train.shape)
# Out:
# resampling time series...
# Training data shape BEFORE resampling: (20827, 150, 2)
# Training data shape AFTER resampling: (20827, 75, 2)

# %%
########### FIT K-MEANS ##############
print('\nperforming time-series kmeans clustering...')
print()
#                                                      random_state=0, 
km = TimeSeriesKMeans(n_clusters=args.nclus[0], verbose=True,metric='euclidean', n_jobs=8)
y_pred = km.fit_predict(X_train)
print()

F = plt.figure(figsize=(20,10))
for yi in range(args.nclus[0]):
    if args.nclus[0] % 5 == 0: 
        nrows = int(args.nclus[0] / 5) 
    else: 
        nrows = int(args.nclus[0] / 5)  + 1

    plt.subplot(nrows, 5, yi + 1)
    for xx in X_train[y_pred == yi][0:250]:
        plt.plot(xx[:,0], "r-", alpha=.05)
        plt.plot(xx[:,1], "b-", alpha=.05)

    plt.title(f'cluster sz: {len(X_train[y_pred == yi])}')
    plt.plot(km.cluster_centers_[yi][:,0], "r-", label='clover')
    plt.plot(km.cluster_centers_[yi][:,1], "b-", label='mscarlet')

    plt.xlim(0, args.resample_sz[0])
    plt.ylim(0, 1)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)

plt.tight_layout()
plt.show()
plt.close('all')
# Out:
# performing time-series kmeans clustering...
#
# 4.041 --> 2.932 --> 2.791 --> 2.734 --> 2.713 --> 2.692 --> 2.662 --> 2.631 --> 2.608 --> 2.594 --> 2.586 --> 2.581 --> 2.579 --> 2.577 --> 2.576 --> 2.575 --> 2.574 --> 2.574 --> 2.574 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 --> 2.573 -->

# %%
########### CALCULATE CLUST PROPORTIONS ##############
print('\nquantifying experiment by cluster proportions...')
lb = LabelEncoder()
y_trt = lb.fit_transform([f'{x}--{y}' for x,y in zip(data.cell__treatment.values, data.dataset.values)])

cm_cnts = {c:np.zeros(args.nclus[0]) for c in lb.classes_} 

for i, clus, grp in zip(range(len(y_pred)), y_pred, y_trt) :
    cm_cnts[lb.classes_[grp]][clus] += 1

cm_prob = {k:v/np.sum(v) for k,v in cm_cnts.items()}

labels = [k for k,v in cm_prob.items()]
cm = np.stack([v for k,v in cm_prob.items()], axis=0)
# Out:
# quantifying experiment by cluster proportions...

# %%
########### PLOT CLUSTER CORR ##############

corr = np.corrcoef(cm, rowvar=False)

f = plt.figure(figsize=(7,7))
ax = sbn.clustermap(
    corr, 
    vmin=-1, vmax=1, center=0,
)
plt.show()
plt.close('all')

# %%
lb.classes_
# Out:
# array(['efm192a__A1160V_untreated--H210820',
#        'efm192a__A355Qfs76_untreated--H210827_Set1',
#        'efm192a__A37T_untreated--H210827_Set2',
#        'efm192a__D639E_untreated--H210827_Set1',
#        'efm192a__G778P780dup_untreated--H210820',
#        'efm192a__I767M_untreated--H210827_Set2',
#        'efm192a__L313V_untreated--H210827_Set2',
#        'efm192a__L755T759del_untreated--H210827_Set1',
#        'efm192a__L785F_untreated--H210820',
#        'efm192a__L869R_untreated--H210820',
#        'efm192a__R47C_untreated--H210827_Set2',
#        'efm192a__R678Q_untreated--H210827_Set1',
#        'efm192a__S310Y_untreated--H210827_Set2',
#        'efm192a__T733I_untreated--H210827_Set1',
#        'efm192a__V424I_untreated--H210827_Set1',
#        'efm192a__V842I_untreated--H210827_Set1',
#        'efm192a__Y64F_untreated--H210827_Set2',
#        'efm192a__Y772V773insRDGE_untreated--H210827_Set2',
#        'efm192a__nd611_untreated--H210820',
#        'efm192a__nd611_untreated--H210827_Set1',
#        'efm192a__nd611_untreated--H210827_Set2',
#        'efm192a__t798i_untreated--H210820',
#        'efm192a__t798i_untreated--H210827_Set1',
#        'efm192a__t798i_untreated--H210827_Set2',
#        'efm192a__wt_untreated--H210820',
#        'efm192a__wt_untreated--H210827_Set1',
#        'efm192a__wt_untreated--H210827_Set2',
#        'efm192a_erk_akt__A1039T_untreated--H210604_Set1',
#        'efm192a_erk_akt__A355Qfs76_untreated--H210618_Set2',
#        'efm192a_erk_akt__A37T_untreated--H210618_Set1',
#        'efm192a_erk_akt__D277H_untreated--H210521_Set1',
#        'efm192a_erk_akt__D638H_untreated--H210521_Set1',
#        'efm192a_erk_akt__D639E_untreated--H210618_Set2',
#        'efm192a_erk_akt__D873G_untreated--H210521_Set1',
#        'efm192a_erk_akt__D933Y_untreated--H210528_Set1',
#        'efm192a_erk_akt__E405D_untreated--H210528_Set2',
#        'efm192a_erk_akt__E939G_untreated--H210528_Set1',
#        'efm192a_erk_akt__E975Q_untreated--H210604_Set2',
#        'efm192a_erk_akt__F976L_untreated--H210528_Set2',
#        'efm192a_erk_akt__F976L_untreated--H210917_EFM192A',
#        'efm192a_erk_akt__G1055C_untreated--H210521_Set1',
#        'efm192a_erk_akt__G727A_untreated--H210604_Set1',
#        'efm192a_erk_akt__G778P780dup_untreated--H210917_EFM192A',
#        'efm192a_erk_akt__G778S779insLPS_untreated--H210521_Set1',
#        'efm192a_erk_akt__H470Q_untreated--H210521_Set1',
#        'efm192a_erk_akt__H878Y_untreated--H210521_Set2',
#        'efm192a_erk_akt__I767M_untreated--H210618_Set1',
#        'efm192a_erk_akt__L313V_untreated--H210618_Set1',
#        'efm192a_erk_akt__L662V_untreated--H210521_Set2',
#        'efm192a_erk_akt__L755S_untreated--H210528_Set2',
#        'efm192a_erk_akt__M833I_untreated--H210521_Set2',
#        'efm192a_erk_akt__M889I_untreated--H210604_Set1',
#        'efm192a_erk_akt__N427K_untreated--H210521_Set2',
#        'efm192a_erk_akt__N488S_untreated--H210604_Set1',
#        'efm192a_erk_akt__N488S_untreated--H210917_EFM192A',
#        'efm192a_erk_akt__P122L_untreated--H210528_Set2',
#        'efm192a_erk_akt__P122L_untreated--H210917_EFM192A',
#        'efm192a_erk_akt__P232S_untreated--H210521_Set2',
#        'efm192a_erk_akt__P416T_untreated--H210514_Set2',
#        'efm192a_erk_akt__P523S_untreated--H210604_Set2',
#        'efm192a_erk_akt__P579L_untreated--H210528_Set1',
#        'efm192a_erk_akt__P702L_untreated--H210514_Set2',
#        'efm192a_erk_akt__Q1206K_untreated--H210604_Set1',
#        'efm192a_erk_akt__R190Q_untreated--H210521_Set2',
#        'efm192a_erk_akt__R203P_untreated--H210514_Set2',
#        'efm192a_erk_akt__R288Q_untreated--H210528_Set1',
#        'efm192a_erk_akt__R340G_untreated--H210514_Set2',
#        'efm192a_erk_akt__R34W_untreated--H210604_Set2',
#        'efm192a_erk_akt__R456C_untreated--H210514_Set2',
#        'efm192a_erk_akt__R47C_untreated--H210618_Set1',
#        'efm192a_erk_akt__R678Q_untreated--H210618_Set2',
#        'efm192a_erk_akt__R929W_untreated--H210604_Set2',
#        'efm192a_erk_akt__S305C_untreated--H210528_Set2',
#        'efm192a_erk_akt__S305C_untreated--H210917_EFM192A',
#        'efm192a_erk_akt__S310Y_untreated--H210618_Set1',
#        'efm192a_erk_akt__S609C_untreated--H210514_Set2',
#        'efm192a_erk_akt__S963_untreated--H210604_Set2',
#        'efm192a_erk_akt__S963_untreated--H210917_EFM192A',
#        'efm192a_erk_akt__T297I_untreated--H210521_Set2',
#        'efm192a_erk_akt__T479M_untreated--H210514_Set2',
#        'efm192a_erk_akt__T733I_untreated--H210618_Set2',
#        'efm192a_erk_akt__T733I_untreated--H210917_EFM192A',
#        'efm192a_erk_akt__T862S_untreated--H210528_Set1',
#        'efm192a_erk_akt__V424I_untreated--H210618_Set2',
#        'efm192a_erk_akt__V697L_untreated--H210528_Set1',
#        'efm192a_erk_akt__V797A_untreated--H210604_Set2',
#        'efm192a_erk_akt__V842I_untreated--H210618_Set2',
#        'efm192a_erk_akt__W482Gfs74_untreated--H210604_Set2',
#        'efm192a_erk_akt__W825_untreated--H210604_Set1',
#        'efm192a_erk_akt__W906C_untreated--H210521_Set1',
#        'efm192a_erk_akt__Y64F_untreated--H210618_Set1',
#        'efm192a_erk_akt__Y772A775dup_untreated--H210604_Set1',
#        'efm192a_erk_akt__Y772V773insRDGE_untreated--H210618_Set1',
#        'efm192a_erk_akt__d769y_untreated--H210514_Set1',
#        'efm192a_erk_akt__e717k_untreated--H210514_Set1',
#        'efm192a_erk_akt__e744d_untreated--H210514_Set1',
#        'efm192a_erk_akt__g621afs31_untreated--H210514_Set1',
#        'efm192a_erk_akt__i435l_untreated--H210514_Set1',
#        'efm192a_erk_akt__i886m_untreated--H210514_Set1',
#        'efm192a_erk_akt__l43v_untreated--H210514_Set1',
#        'efm192a_erk_akt__nd611_untreated--H210514_Set1',
#        'efm192a_erk_akt__nd611_untreated--H210514_Set2',
#        'efm192a_erk_akt__nd611_untreated--H210521_Set1',
#        'efm192a_erk_akt__nd611_untreated--H210521_Set2',
#        'efm192a_erk_akt__nd611_untreated--H210528_Set1',
#        'efm192a_erk_akt__nd611_untreated--H210528_Set2',
#        'efm192a_erk_akt__nd611_untreated--H210604_Set1',
#        'efm192a_erk_akt__nd611_untreated--H210604_Set2',
#        'efm192a_erk_akt__nd611_untreated--H210618_Set1',
#        'efm192a_erk_akt__nd611_untreated--H210618_Set2',
#        'efm192a_erk_akt__nd611_untreated--H210917_EFM192A',
#        'efm192a_erk_akt__t798i_untreated--H210514_Set1',
#        'efm192a_erk_akt__t798i_untreated--H210514_Set2',
#        'efm192a_erk_akt__t798i_untreated--H210521_Set1',
#        'efm192a_erk_akt__t798i_untreated--H210521_Set2',
#        'efm192a_erk_akt__t798i_untreated--H210528_Set1',
#        'efm192a_erk_akt__t798i_untreated--H210528_Set2',
#        'efm192a_erk_akt__t798i_untreated--H210604_Set1',
#        'efm192a_erk_akt__t798i_untreated--H210604_Set2',
#        'efm192a_erk_akt__t798i_untreated--H210618_Set1',
#        'efm192a_erk_akt__t798i_untreated--H210618_Set2',
#        'efm192a_erk_akt__t798i_untreated--H210917_EFM192A',
#        'efm192a_erk_akt__wt_untreated--H210514_Set1',
#        'efm192a_erk_akt__wt_untreated--H210514_Set2',
#        'efm192a_erk_akt__wt_untreated--H210521_Set1',
#        'efm192a_erk_akt__wt_untreated--H210521_Set2',
#        'efm192a_erk_akt__wt_untreated--H210528_Set1',
#        'efm192a_erk_akt__wt_untreated--H210528_Set2',
#        'efm192a_erk_akt__wt_untreated--H210604_Set1',
#        'efm192a_erk_akt__wt_untreated--H210604_Set2',
#        'efm192a_erk_akt__wt_untreated--H210618_Set1',
#        'efm192a_erk_akt__wt_untreated--H210618_Set2',
#        'efm192a_erk_akt__wt_untreated--H210917_EFM192A'], dtype='<U56')

# %%
########### DIM. REDUCTION ##############
_sens = args.sensitive_line[0].upper()
_res = args.resistant_line[0].upper()
_drug = args.drug[0].lower()

print('\nperforming dim. reduction (pca)...')
pca = PCA(n_components=2)
PCs = pca.fit_transform(cm)

print('PCA explained variance ratio:', pca.explained_variance_ratio_)
print('PC shape:', PCs.shape)


#old
#res = pd.DataFrame({'pc1': PCs[:,0], 'pc2':PCs[:,1], 'treatment':[x.split('--')[0].split('_')[-1] for x in lb.classes_], 'cell_line':[x.split('_')[4] for x in lb.classes_]})

#new 
res = pd.DataFrame({'pc1': PCs[:,0], 'pc2':PCs[:,1], 'treatment':[x.split('--')[0].split('_')[-1] for x in lb.classes_], 'cell_line':[x.split('_')[0] for x in lb.classes_]})


plt.figure(figsize=(7,7))
sbn.scatterplot(x='pc1', y='pc2', data=res, hue='cell_line', style='treatment', s=300)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

plt.figure(figsize=(7,7))
sbn.scatterplot(x='pc1', y='pc2', data=res[lambda x: (x.cell_line.isin([_sens, _res]))], hue='cell_line', style='treatment', s=300)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
plt.close('all')
        
res.head()
# Out:
# performing dim. reduction (pca)...
# PCA explained variance ratio: [0.57504387 0.20259233]
# PC shape: (133, 2)
# No handles with labels found to put in legend.
#         pc1       pc2  treatment cell_line
# 0  0.263873 -0.145745  untreated   efm192a
# 1  0.069642  0.103897  untreated   efm192a
# 2 -0.176814  0.304833  untreated   efm192a
# 3  0.163820  0.035080  untreated   efm192a
# 4 -0.162665 -0.204504  untreated   efm192a

# %%
  ########### TRAIN CLASSIFIER ##############
        print('\ntraining classifier...')
        
        print('sensitive line:', _sens)
        print('resistant line:', _res)
        print('drug:', _drug)
        
        res_drug = res[lambda x: (x.cell_line.isin([_sens, _res])) & (x.treatment == _drug)]
        print('drug + WT df size: ', res_drug.shape)

        X = res_drug[['pc1', 'pc2']].values
        y_res = ((res_drug.cell_line == _res).values)
        y_sens = ((res_drug.cell_line == _sens).values)

        assert (y_res == ~y_sens).all(), 'y class label assignment has more than 2 classes...'
        
        y = 1*y_sens
        
        print('X train shape:', X.shape)
        print('# neg class (resistant):', np.sum(y_res))
        print('# pos class (sensitive):', np.sum(y_sens))
         
        #                                                 , random_state=0
        model = SVC(kernel='linear', C=10, probability=True)
        model.fit(X,y) 
        y_pred = model.predict(X)
        accuracy = accuracy_score(y, y_pred)
        
        plt.figure(figsize=(10, 5))
        plt.subplots_adjust(bottom=.2, top=.95)
        
        #xx = np.linspace(-1, 1, 100)
        #yy = np.linspace(-1, 1, 100).T
        xx = np.linspace(min(X[:,0]), max(X[:,0]), 100)
        yy = np.linspace(min(X[:,1]), max(X[:,1]), 100).T
        xx, yy = np.meshgrid(xx, yy)
        Xfull = np.c_[xx.ravel(), yy.ravel()]
        
        # View probabilities:
        probas = model.predict_proba(Xfull)
        n_classes = np.unique(y_pred).size
        class_names = ['resistant', 'sensitive']
        name = 'Support Vector Classifier'
        for k in range(n_classes):
            plt.subplot(1, n_classes, 0 * n_classes + k + 1)
            plt.title("%s class" % class_names[k])
            if k == 0:
                plt.ylabel(name)
            imshow_handle = plt.imshow(probas[:, k].reshape((100, 100)),
                                       extent=(-1, 1, -1, 1), origin='lower')
            plt.xticks(())
            plt.yticks(())
            idx = (y_pred == k)
            if idx.any():
                plt.scatter(X[idx, 0], X[idx, 1], marker='o', c='w', edgecolor='k')
        
        ax = plt.axes([0.15, 0.04, 0.7, 0.05])
        plt.title("Probability")
        plt.colorbar(imshow_handle, cax=ax, orientation='horizontal')

        plt.savefig(output_dir + '/classifier_results.png',bbox_inches='tight')
        plt.close('all')
        
        ########### APPLY TO UNLABELED CELL LINES ##############
        print('\npredicting unlabeled sensitivities...')
        _other = res[lambda x: ~(x.cell_line.isin([args.sensitive_line[0].lower(), args.resistant_line[0].lower()])) & (x.treatment == args.drug[0].lower())].reset_index(drop=True)

        X_all = _other[['pc1', 'pc2']].values

        y_hat = model.predict_proba(X_all)

        pres = pd.DataFrame({'prob_res':y_hat[:,0], 'prob_sens':y_hat[:,1]})
        prob_res = pd.concat([_other, pres], axis=1) 
        prob_res = prob_res.assign(call=[['res','sens'][np.argmax([x,y])] for x,y in zip(prob_res.prob_res, prob_res.prob_sens)])
        
        ########### SAVE RESULTS ##############
        print('\nsaving results...')
        
        prob_res.to_csv(output_dir + '/unlabeled_lines_results.csv') 
        
        run_res = pd.DataFrame({'accuracy(train)': accuracy, 
                                'pc1_var':pca.explained_variance_ratio_[0], 
                                'pc2_var':pca.explained_variance_ratio_[1], 
                                'kmeans_inertia': km.inertia_,
                                'res_line':_res, 
                                'sens_line': _sens,
                                'drug':_drug, 
                                'nclus':args.nclus[0],
                                'resample_sz': args.resample_sz[0],
                                'load': args.load[0], 
                                'run_id':run_id}, index=[0])
        
        run_res.to_csv(output_dir + '/run_results.csv')

# %%
  ########### TRAIN CLASSIFIER ##############
        print('\ntraining classifier...')
        
        print('sensitive line:', _sens)
        print('resistant line:', _res)
        print('drug:', _drug)
        
        res_drug = res[lambda x: (x.cell_line.isin([_sens, _res])) & (x.treatment == _drug)]
        print('drug + WT df size: ', res_drug.shape)

        X = res_drug[['pc1', 'pc2']].values
        y_res = ((res_drug.cell_line == _res).values)
        y_sens = ((res_drug.cell_line == _sens).values)

        assert (y_res == ~y_sens).all(), 'y class label assignment has more than 2 classes...'
        
        y = 1*y_sens
        
        print('X train shape:', X.shape)
        print('# neg class (resistant):', np.sum(y_res))
        print('# pos class (sensitive):', np.sum(y_sens))
         
        #                                                 , random_state=0
        model = SVC(kernel='linear', C=10, probability=True)
        model.fit(X,y) 
        y_pred = model.predict(X)
        accuracy = accuracy_score(y, y_pred)
        
        plt.figure(figsize=(10, 5))
        plt.subplots_adjust(bottom=.2, top=.95)
        
        #xx = np.linspace(-1, 1, 100)
        #yy = np.linspace(-1, 1, 100).T
        xx = np.linspace(min(X[:,0]), max(X[:,0]), 100)
        yy = np.linspace(min(X[:,1]), max(X[:,1]), 100).T
        xx, yy = np.meshgrid(xx, yy)
        Xfull = np.c_[xx.ravel(), yy.ravel()]
        
        # View probabilities:
        probas = model.predict_proba(Xfull)
        n_classes = np.unique(y_pred).size
        class_names = ['resistant', 'sensitive']
        name = 'Support Vector Classifier'
        for k in range(n_classes):
            plt.subplot(1, n_classes, 0 * n_classes + k + 1)
            plt.title("%s class" % class_names[k])
            if k == 0:
                plt.ylabel(name)
            imshow_handle = plt.imshow(probas[:, k].reshape((100, 100)),
                                       extent=(-1, 1, -1, 1), origin='lower')
            plt.xticks(())
            plt.yticks(())
            idx = (y_pred == k)
            if idx.any():
                plt.scatter(X[idx, 0], X[idx, 1], marker='o', c='w', edgecolor='k')
        
        ax = plt.axes([0.15, 0.04, 0.7, 0.05])
        plt.title("Probability")
        plt.colorbar(imshow_handle, cax=ax, orientation='horizontal')

        plt.savefig(output_dir + '/classifier_results.png',bbox_inches='tight')
        plt.close('all')

# %%
        ########### APPLY TO UNLABELED CELL LINES ##############
        print('\npredicting unlabeled sensitivities...')
        _other = res[lambda x: ~(x.cell_line.isin([args.sensitive_line[0].lower(), args.resistant_line[0].lower()])) & (x.treatment == args.drug[0].lower())].reset_index(drop=True)

        X_all = _other[['pc1', 'pc2']].values

        y_hat = model.predict_proba(X_all)

        pres = pd.DataFrame({'prob_res':y_hat[:,0], 'prob_sens':y_hat[:,1]})
        prob_res = pd.concat([_other, pres], axis=1) 
        prob_res = prob_res.assign(call=[['res','sens'][np.argmax([x,y])] for x,y in zip(prob_res.prob_res, prob_res.prob_sens)])

# %%
        ########### SAVE RESULTS ##############
        print('\nsaving results...')
        
        prob_res.to_csv(output_dir + '/unlabeled_lines_results.csv') 
        
        run_res = pd.DataFrame({'accuracy(train)': accuracy, 
                                'pc1_var':pca.explained_variance_ratio_[0], 
                                'pc2_var':pca.explained_variance_ratio_[1], 
                                'kmeans_inertia': km.inertia_,
                                'res_line':_res, 
                                'sens_line': _sens,
                                'drug':_drug, 
                                'nclus':args.nclus[0],
                                'resample_sz': args.resample_sz[0],
                                'load': args.load[0], 
                                'run_id':run_id}, index=[0])
        
        run_res.to_csv(output_dir + '/run_results.csv')

# %%
class O: 
    def __init__(self): 
        O.load = ['raw']
        O.data = ['/home/teddy/local/live_cell_reporter_imaging/data/HER2_SKBR3_data_6-7-21/HER2_SKBR3_data_6-7-21/']
args = O()

print('\nsloading data...')
load = args.load[0].lower()
data_dir = args.data[0]
datasets = [x for x in os.listdir(data_dir) if os.path.isdir(data_dir + x)]

print('# of datasets to load:',len(datasets))

series_sel = pd.read_csv(data_dir + datasets[0] + '/' + load + '/clover_all_cell.csv').columns[1:-3]

_datas = []
for dataset in datasets: 
    cl_path = data_dir + dataset + '/' + load + '/clover_all_cell.csv'
    ms_path = data_dir + dataset + '/' + load + '/mscarlet_all_cell.csv'
    _clover = pd.read_csv(cl_path)
    _mscarl = pd.read_csv(ms_path)
    _data = _clover.merge(_mscarl, on=['track_index', 'cell__treatment'], how='inner')
    _data = _data.assign(dataset=dataset)
    _datas.append(_data)

data = pd.concat(_datas, axis=0)

clover_sel = [f'{x}_x' for x in series_sel]
mscarl_sel = [f'{x}_y' for x in series_sel]

data = data.assign(drug = [x.split('_', maxsplit=5)[-1] for x in data.cell__treatment])
data = data.assign(cell_line = [x.split('_', maxsplit=5)[0] for x in data.cell__treatment])
data = data.assign(mutant = [x.split('_', maxsplit=5)[-2] for x in data.cell__treatment])

data.head()
# Out:
# sloading data...
# # of datasets to load: 13
#                                  track_index       0_x      15_x      30_x  \
# 0   3_1000011860_skbr3_erk_akt__WT_untreated  0.939628  0.891530  0.562608
# 1  79_1000288819_skbr3_erk_akt__WT_untreated  0.716700  0.828169  0.846997
# 2  78_1000285319_skbr3_erk_akt__WT_untreated  0.893122  0.918505  0.800166
# 3   1_1000002701_skbr3_erk_akt__WT_untreated  0.925266  0.887206  0.927599
# 4  78_1000282488_skbr3_erk_akt__WT_untreated  1.022995  0.889429  0.860142
#
#        45_x      60_x      75_x      90_x     105_x     120_x  ...  2805_y  \
# 0  0.834245  1.108023  0.760721  0.659259  0.557796  0.456334  ...     NaN
# 1  0.810356  0.766408  0.789658  0.742649  0.811046  0.832033  ...     NaN
# 2  0.872648  0.839871  0.880530  0.663143  0.968198  0.936171  ...     NaN
# 3  0.950207  0.866647  0.869601  0.897597  0.888514  0.876737  ...     NaN
# 4  0.693650  0.631249  0.591991  0.597955  0.685731  0.712077  ...     NaN
#
#    2820_y  2835_y  2850_y  2865_y  2880_y  2895_y       drug  cell_line  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN  untreated      skbr3
# 1     NaN     NaN     NaN     NaN     NaN     NaN  untreated      skbr3
# 2     NaN     NaN     NaN     NaN     NaN     NaN  untreated      skbr3
# 3     NaN     NaN     NaN     NaN     NaN     NaN  untreated      skbr3
# 4     NaN     NaN     NaN     NaN     NaN     NaN  untreated      skbr3
#
#    mutant
# 0      WT
# 1      WT
# 2      WT
# 3      WT
# 4      WT
#
# [5 rows x 398 columns]

# %%
data.columns
# Out:
# Index(['track_index', '0_x', '15_x', '30_x', '45_x', '60_x', '75_x', '90_x',
#        '105_x', '120_x',
#        ...
#        '2805_y', '2820_y', '2835_y', '2850_y', '2865_y', '2880_y', '2895_y',
#        'drug', 'cell_line', 'mutant'],
#       dtype='object', length=398)
